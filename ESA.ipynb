# %% [markdown]
# # Course Content Overlap

# %%
import os                                                     # TO READ WIKIARTICLES.
import re
import json                                                   # TO READ FROM .json FILE.
import math                                                   # TO CALCULATE nDCG
import pandas as pd                                           # TO READ COURSE DATA.
import numpy as np                                            # TO SAVE DICTIONARY.  
from nltk.tokenize import word_tokenize                       # TO CLEAN DATA.
from nltk.corpus import stopwords                             # TO CLEAN DATA.
from sklearn.feature_extraction.text import TfidfVectorizer   # TO EXTRACT PHRASES.
import scipy.sparse                                           # TO SAVE MODEL.
from sklearn.metrics.pairwise import cosine_similarity        # FOR COSINE SIMILARITY MEASURE
from nltk.stem import PorterStemmer
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shanu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shanu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
class Preprocessing:
    
    def __init__(self, phrases, abbreviation, with_stemming):
        self.stop_words = list(set(stopwords.words('english')))
        self.common_word = ['introduction', 'overview', 'basic', 'various', 'topics', 'review', 'course', 'student', 'content', 'academic', 'necessary', 'different']
        self.stop_words = self.stop_words + self.common_word
        self.phrases = phrases
        self.abbreviations = abbreviations
        self.with_stemming = with_stemming

        
    def cleanData(self, text):
        """
            Input   : text to be cleaned.
            Returns : cleaned text string.
        """
        text = text.replace("'"," ").replace("\""," ").replace(";"," ").replace(","," ").replace("-"," ").replace(":"," ").replace("["," ").replace("]"," ").replace("."," ").replace("/"," ").lower()
        text = word_tokenize(text)
        if self.with_stemming == 'yes':
            ps = PorterStemmer()
            text = [ps.stem(token) for token in text if (token.replace('_', '').isalnum() and not token.replace('_', '').isnumeric() and token not in self.stop_words and len(token)>1) ]
        else:
            text = [token for token in text if (token.replace('_', '').isalnum() and not token.replace('_', '').isnumeric() and token not in self.stop_words and len(token)>1) ]
        return " ".join(text)
    
    def phrase_replacement(self, intext):
        outtext = intext
        for phrase in self.phrases:
            phrase_ = phrase.replace("_", " ")
            if phrase_ in outtext.lower():
                outtext = outtext.lower().replace(" "+phrase_+" ", " "+phrase+" ")
        return outtext
    
    
    def abbreviation_replacement(self, intext):
        outtext = intext
        for abbreviation in self.abbreviations:
            if abbreviation in outtext:
                outtext = outtext.replace(" "+abbreviation+" ", " "+abbreviation+" "+self.abbreviations[abbreviation]+" ")
            elif self.abbreviations[abbreviation] in outtext:
                outtext = outtext.replace(" "+self.abbreviations[abbreviation]+" ", " "+abbreviation+" "+self.abbreviations[abbreviation]+" ")
        return outtext
    

    def readWikipediaData(self, base_directory):
        """
            Input   : directory path.
            Returns : Wikipedia article titles and contents ordered list.
        """
        files = os.listdir(base_directory)
        content = {}

        for file in files:
            file_path = base_directory + file
            data = json.load(open(file_path,"r",encoding="utf-8"))
            for title in data['pages']:
                details = data['pages'][title]['text'] + ' ' + title
                details = self.cleanData(details)
                content[title] = self.phrase_replacement(self.abbreviation_replacement(details))
        return content


    def readCourseData(self, document_filename):
        """
            Input   : File path.
            Returns : Course titles and Course details ordered list.
        """
        df = pd.read_csv(document_filename)
        content = {}
        for index,row in df.iterrows():
            details = row['description']+' '+row['content'] +' ' +row['coursename']
            details = self.cleanData(details)
            course_detail = self.phrase_replacement(self.abbreviation_replacement(details))
#             course_detail = row['description']+' '+row['content']
            title = row['courseno'] + ' - ' + row['coursename']
            content[title] = course_detail
        return content
    
    
    def readDictionary(self, base_directory):
        """
            Input   : directory path.
            Returns : Wikipedia article titles and contents ordered list.
        """
        content = {}

        data = json.load(open(base_directory,"r",encoding="utf-8"))
        for title in data:
            temp_title = ''
            temp = title.split('-')
            for i in temp:
                if not re.search('\d+', i):
                    temp_title += i
            details = data[title] + ' ' + temp_title
            details = self.cleanData(details)
            content[title] = self.phrase_replacement(self.abbreviation_replacement(details))
        return content

# %%
class Evaluation:
    
    def __init__(self, filename, titles, similarity_matrix, dept, scope):
        self.filename = filename
        self.titles = titles
        self.num_courses = len(titles)
        self.similarity_matrix = similarity_matrix
        self.dept1, self.dept2 = dept.split("-")
        self.scope = scope
        
    def lists_to_dict(self, keys, values):
        dictionary = {}
        for key, value in zip(keys, values):
            dictionary[key] = value
        return dictionary
        
    def createEvaluationMatrix(self):
        """
            Input   : Path to evaluation data, number of courses, list of course_titles
            Returns : A binary Relevance feedback matrix.
        """
        with open(self.filename) as file:
            eval_data = file.read().strip()
            eval_data = eval(eval_data)

        self.eval_matrix = np.zeros((self.num_courses, self.num_courses), dtype=int)
        np.fill_diagonal(self.eval_matrix, 1)

        for pair in eval_data:
            index_1  = self.titles.index(pair[0])
            index_2  = self.titles.index(pair[1])
            self.eval_matrix[index_1][index_2] = 1
            
        self.eval_matrix = np.maximum(self.eval_matrix, self.eval_matrix.T)
        return self.eval_matrix

    def getPrunedMatrix(self, matrix, dept):
        """
            Input   : matrix, list of courses, department code.
            Returns : matrix - department x all departments.
        """
        min_index = 0
        max_index = 0
        for i in range(len(self.titles)):
            if(dept in self.titles[i] and min_index==0):
                min_index = i
            elif(dept in self.titles[i] and min_index!=0):
                max_index = i
            elif(min_index!=0 and max_index!=0):
                break
        return matrix[min_index : max_index+1]

    def getNDCG(self, a, b):
        """
            Input   : The obtained rankings, and expected relevance.
            Returns : nDCG value.
        """
        dcg = 0
        for i in range(0,len(a)):
            dcg += b[a[i]]/math.log2(i+2)

        idcg = 0
        num_relevant = int(np.sum(b))
        for i in range(0,num_relevant):
            idcg += 1/math.log2(i+2)

        return dcg/idcg
    
    def evaluation(self):
        """
            Input   : The similarity matrix and evaluation matrix.
            Returns : Course wise nDCG values and average nDCG values.
        """
        ndcg_vals = []
        num_courses = len(self.eval_matrix.T[0])
        
        for i in range(num_courses):
            if sum(self.eval_matrix[i]) > 0:
                ranked_course_indices = np.argsort(-1*self.similarity_matrix[i])
                if self.scope ==  "one-vs-all":
                    ndcg_vals.append(self.getNDCG(ranked_course_indices, self.eval_matrix[i]))
                else:
                    ndcg_vals.append(self.getNDCG(ranked_course_indices, self.eval_matrix[i]))
            else:
                ndcg_vals.append(float("nan"))

        return ndcg_vals

    def printCourseWiseNDCGValues(self, ndcg_vals, titles):
        """
            Input   : Course wise nDCG values, department titles.
            Prints  : Course wise nDCG values, average nDCG vale.
        """
        for i in range(len(titles)):
            print(titles[i]," - ",ndcg_vals[i])
        count=0
        for i in ndcg_vals:
            if not math.isnan(i):
                count+=1
        print("\n Average nDCG = ", np.nansum(ndcg_vals)/count)
        
        
    def evaluate(self):
        self.eval_matrix = self.createEvaluationMatrix()
        dept_titles = self.getPrunedMatrix(self.titles, self.dept1)
        
        np.fill_diagonal(self.eval_matrix, 0)
        np.fill_diagonal(self.similarity_matrix, 0)
        if self.scope == "all-vs-all":
            pass
        elif self.scope == "one-vs-all":
            self.eval_matrix = self.getPrunedMatrix(self.eval_matrix, self.dept1)
            self.similarity_matrix = self.getPrunedMatrix(self.similarity_matrix, self.dept1)
        elif self.scope == "one-vs-one":
            self.eval_matrix = self.getPrunedMatrix(self.eval_matrix.T, self.dept1).T
            self.eval_matrix = self.getPrunedMatrix(self.eval_matrix, self.dept2)
            
            self.similarity_matrix = self.getPrunedMatrix(self.similarity_matrix.T, self.dept1).T
            self.similarity_matrix = self.getPrunedMatrix(self.similarity_matrix, self.dept2)
        
        ndcg_vals = self.evaluation()
        coursewise_ndcg = self.lists_to_dict(dept_titles, ndcg_vals)
#         self.printCourseWiseNDCGValues(ndcg_vals, dept_titles)
        
        return self.similarity_matrix, self.eval_matrix, coursewise_ndcg
    
    def printing(self, folder, method):
        try:
            cropped_similarity_matrix = np.lad(folder + self.dept + '_' + method + '_similarity_matrix.npy')
            cropped_evaluation_matrix = np.load(folder + self.dept + '_evaluation_matrix.npy')
            cropped_coursewise_ndcg = json.load(open(folder + self.dept + '_' + method + '_coursewise_ndcg.npy', 'r'))
        except:
            cropped_similarity_matrix, cropped_evaluation_matrix, cropped_coursewise_ndcg = self.evaluate()

            np.save(folder + dept + '_' + method + '_similarity_matrix.npy', cropped_similarity_matrix)
            np.save(folder + dept + '_evaluation_matrix.npy', cropped_evaluation_matrix)
            json.dump(cropped_coursewise_ndcg, open(folder + dept + '_' + method + '_coursewise_ndcg.npy', 'w'))

        count, sum_ndcg = 0, 0
        for course in cropped_coursewise_ndcg:
            ndcg_score = cropped_coursewise_ndcg[course]
            print(course, " - ", ndcg_score)
            if not math.isnan(ndcg_score):
                sum_ndcg += ndcg_score
                count+=1
        print("\n Average nDCG = ", sum_ndcg/count)

        return cropped_similarity_matrix, cropped_evaluation_matrix, cropped_coursewise_ndcg

# %% [markdown]
# # ESA

# %%
class ESA:
    def __init__(self, wiki, documents, queries, mode):
        self.wiki = wiki
        self.documents = documents
        self.queries = queries
        self.mode = mode
        
    def dict_to_list(self, dicti):
        titles, contents = [], []
        for key in dicti:
            titles.append(key)
            contents.append(dicti[key])
        return titles, contents
        
    def document_indexing(self, titles):
        content2index = {}
        index2content = {}
        for i in range(len(titles)):
            content2index[titles[i]] = i
            index2content[i] = titles[i]
        return content2index, index2content
    
    def getTFIDFModel(self, documents):
        """
            Input   : list of document contents.
            Returns : TF-IDF Model and TF-IDF Matrix.
        """
        tfidf_vectorizer = TfidfVectorizer(stop_words='english',use_idf=True)
        tfidf_vectorizer.fit(documents)
        document_tfidf_matrix = tfidf_vectorizer.transform(documents)
        vocab = tfidf_vectorizer.vocabulary_
        return document_tfidf_matrix, vocab
    
    def esa_matrix_computation(self, titles, details, vocab, document_matrix):
        num_courses = len(titles)
        esa_matrix = np.zeros((num_courses, self.num_concepts), dtype=float)
        words_not_in_wiki = []
        for i in range(len(titles)):
            i_content = set(details[i].split())
            for word in i_content:
                if word in self.wiki_vocab:
                    word_index_in_documents = vocab[word]
                    word_index_in_wiki    = self.wiki_vocab[word]
                    documents_tf_idf        = document_matrix[word_index_in_documents, i]
                    esa_matrix[i] += documents_tf_idf * self.term_concept_matrix.T[word_index_in_wiki]
                else:
                    words_not_in_wiki.append(word)
        return esa_matrix
    
    def computation(self):
        wiki_titles, wiki_contents = self.dict_to_list(self.wiki)
#         concept2index, index2concept = self.document_indexing(wiki_titles)
        self.term_concept_matrix, self.wiki_vocab = self.getTFIDFModel(wiki_contents)
        self.num_concepts = len(wiki_titles)
        
        document_titles, document_contents = self.dict_to_list(self.documents)
#         document2index, index2document = self.document_indexing(document_titles)
        term_document_matrix, doc_vocab = self.getTFIDFModel(document_contents)
        
        document_esa_matrix = self.esa_matrix_computation(document_titles, document_contents, doc_vocab, term_document_matrix.T)
        
        if self.mode != "same":
            query_titles, query_contents = self.dict_to_list(self.queries)
            query2index, index2query = self.document_indexing(query_titles)
            term_query_matrix, query_vocab = self.getTFIDFModel(query_contents)
            query_esa_matrix = self.esa_matrix_computation(query_titles, query_contents, query_vocab, term_query_matrix.T)
            return document_esa_matrix, query_esa_matrix, cosine_similarity(document_esa_matrix, query_esa_matrix)
        
        return document_esa_matrix, document_esa_matrix, cosine_similarity(document_esa_matrix)

# %%
folder = '../codes/dataset/saved/without_phrases/'

phrases = []
abbreviations = {}
with_stemming = 'no'

course_detail_path = "../codes/dataset/CourseData.csv"
preprocessing = Preprocessing(phrases, abbreviations, with_stemming)
document_content = preprocessing.readCourseData(course_detail_path)
try:
    wiki_document_esa_matrix = np.load(folder + 'wiki_document_esa_matrix.npy')
    wiki_query_esa_matrix = np.load(folder + 'wiki_query_esa_matrix.npy')
    wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')
except:
    wikipedia_articles_path = "../codes/dataset/QueriedWikipediaArticles/"

    base_content = preprocessing.readWikipediaData(wikipedia_articles_path)
    document_content = preprocessing.readCourseData(course_detail_path)
    
    esa = ESA(base_content, document_content, document_content, "same")
    wiki_document_esa_matrix, wiki_query_esa_matrix, wiki_esa_similarity_matrix = esa.computation()

    np.save(folder + 'wiki_document_esa_matrix.npy', wiki_document_esa_matrix)
    np.save(folder + 'wiki_query_esa_matrix.npy', wiki_query_esa_matrix)
    np.save(folder + 'wiki_esa_similarity_matrix.npy', wiki_esa_similarity_matrix)

# %% [markdown]
# For CS vs CS courses

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'CS-CS'
scope = 'one-vs-one'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
cs_cs_wiki_esa_similarity_matrix, cs_cs_wiki_esa_evaluation_matrix, cs_cs_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# CS1100 - Introduction to Programming  -  0.973985563224661
# CS1111 - Problem Solving using Computers  -  0.975788054854922
# CS2300 - Foundations of Computer Systems Design  -  0.9604489504159912
# CS2310 - Foundations of Computer Systems Design Lab  -  0.9519709359886506
# CS2700 - Programming and Data Structures  -  0.9183387600570154
# CS2710 - Programming and Data Structures Lab  -  0.9696643615373284
# CS3100 - Paradigms of Programming  -  0.9206307738894893
# CS3300 - Compiler Design  -  0.23540891336663824
# CS3500 - Operating Systems  -  0.9709286432396583
# CS3700 - Introduction to Database Systems  -  nan
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.8733336307416327
# CS5691 - Pattern Recognition and Machine Learning  -  0.9178260148263059
# CS5800 - Advanced Data Structures & Algorithms  -  0.9547851288814769
# CS6014 - Computability and Complexity  -  0.8596941277243692
# CS6015 - Linear Algebra and Random Processes  -  0.86034433104172
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.8199855670628776
# CS6030 - Logic and Combinatorics for Computer Science  -  0.6565425514758003
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.23540891336663824
# CS6130 - Advanced Graph Algorithms  -  0.7122630665145961
# CS6140 - Advanced Programming Laboratory  -  0.9911205770005563
# CS6170 - Randomized Algorithms  -  0.6934264036172708
# CS6230 - CAD for VLSI Systems  -  0.7977738342386859
# CS6251 - Computational Models of Cognition  -  0.4320030606958183
# CS6350 - Computer Vision  -  0.895135413424339
# CS6380 - Artificial Intelligence  -  0.602130428682235
# CS6570 - Secure Systems Engineering  -  0.9193743993997125
# CS6600 - Computer Architecture  -  0.9447176050778178
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.9089869472799491
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.9930783166417602
# CS7016 - Topics In Deep Learning  -  1.0
# CS7111 - Topics in Cryptography  -  1.0
#
#  Average nDCG =  0.8395255019817531

# %% [markdown]
# For CS vs All courses

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'CS-ALL'
scope = 'one-vs-all'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
cs_all_wiki_esa_similarity_matrix, cs_all_wiki_esa_evaluation_matrix, cs_all_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# CS1100 - Introduction to Programming  -  0.9448825279832472
# CS1111 - Problem Solving using Computers  -  0.9137326376230489
# CS2300 - Foundations of Computer Systems Design  -  0.9514618672915927
# CS2310 - Foundations of Computer Systems Design Lab  -  0.8430740355450209
# CS2700 - Programming and Data Structures  -  0.9236472308614703
# CS2710 - Programming and Data Structures Lab  -  0.9263397875421715
# CS3100 - Paradigms of Programming  -  0.8342463567298523
# CS3300 - Compiler Design  -  0.6312770006570017
# CS3500 - Operating Systems  -  0.8473156139468664
# CS3700 - Introduction to Database Systems  -  0.6679417426974276
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.8815466846328809
# CS5691 - Pattern Recognition and Machine Learning  -  0.9306327201623718
# CS5800 - Advanced Data Structures & Algorithms  -  0.8805457551189749
# CS6014 - Computability and Complexity  -  0.8738940453383541
# CS6015 - Linear Algebra and Random Processes  -  0.9523218863834864
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.738746206504391
# CS6030 - Logic and Combinatorics for Computer Science  -  0.8753026578834922
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.6103185763110577
# CS6130 - Advanced Graph Algorithms  -  0.751056647292352
# CS6140 - Advanced Programming Laboratory  -  0.9512957584525317
# CS6170 - Randomized Algorithms  -  0.7771198148031028
# CS6230 - CAD for VLSI Systems  -  0.664787972708243
# CS6251 - Computational Models of Cognition  -  0.6008437789211044
# CS6350 - Computer Vision  -  0.7693035292337096
# CS6380 - Artificial Intelligence  -  0.6902089856584603
# CS6570 - Secure Systems Engineering  -  0.8246060438048115
# CS6600 - Computer Architecture  -  0.9128203855726054
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.8525855577132467
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.9134602175999651
# CS7016 - Topics In Deep Learning  -  0.8315546295836225
# CS7111 - Topics in Cryptography  -  0.766433990956823
#
#  Average nDCG =  0.8319098616564082

# %% [markdown]
# For EE vs EE courses

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'EE-EE'
scope = 'one-vs-one'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_ee_wiki_esa_similarity_matrix, ee_ee_wiki_esa_evaluation_matrix, ee_ee_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# EE1100 - Basic Electrical Engineering  -  0.6212101921659198
# EE1102 - Introduction to Programming  -  nan
# EE1103 - Numerical Methods  -  0.5249810332008933
# EE2015 - Electric Circuits & Networks  -  0.7859852846207472
# EE2016 - Microprocessor Theory+Lab  -  nan
# EE2025 - Engineering Electromagnetics  -  0.8503449055347546
# EE3002 - Analog Circuits  -  0.9186560662081473
# EE3003 - Power Systems  -  0.5
# EE3004 - Control Engineering  -  0.823515575213343
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.6583856728354838
# EE3301 - Introduction to Semiconductor Devices  -  0.9372375429818208
# EE3313 - Device Modelling  -  0.9350976551237904
# EE4140 - Digital Communication Systems  -  0.9043980816456215
# EE4371 - Introduction to Data Structures and Algorithms  -  nan
# EE4502 - Optics for Engineers  -  1.0
# EE4708 - Data Analytics Laboratory  -  0.43067655807339306
# EE5011 - Computer Methods in Electrical Engineering  -  0.6309297535714575
# EE5110 - Probability Foundations for Electrical Engineers  -  0.6537031097682611
# EE5120 - Applied Linear Algebra I for EE  -  0.8854598815714874
# EE5130 - Digital Signal Processing  -  0.824055711564085
# EE5140 - Digital Modulation and Coding  -  0.7611962717758727
# EE5143 - Information Theory  -  1.0
# EE5151 - Communication Techniques  -  0.6521602615416859
# EE5200 - Power Converter Analysis and Design  -  0.7603225892217418
# EE5201 - Modelling and Analysis of Electric Machines  -  0.6663732474096913
# EE5204 - Electric Vehicles and Renewable Energy  -  0.9197207891481876
# EE5212 - Digital Controller for power Applications  -  0.322377339362118
# EE5253 - Computer Methods in Power Systems Analysis  -  0.8424910786679212
# EE5262 - Distributed Generation and Microgrid Systems  -  0.8029580725803853
# EE5310 - Analog Electronic circuits  -  0.9590729006026163
# EE5311 - Digital IC Design  -  0.8502983370860306
# EE5312 - VLSI Technology  -  0.9630942302367672
# EE5313 - Semiconductor Device Modelling  -  0.9565912771023182
# EE5325 - Power Management Integrated Circuits  -  0.6528604065555543
# EE5346 - Introduction to Plastic Electronics  -  0.5
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.3562071871080222
# EE5400 - Analog and Digital Circuits  -  0.7328286204777911
# EE5410 - Introduction to DSP  -  0.7421923726567936
# EE5412 - Mathematical Methods in System Engineering  -  0.8385465274895063
# EE5413 - Linear Dynamical Systems  -  0.9197207891481876
# EE5502 - Optical Engineering  -  1.0
# EE5505 - Wave Propagation in Communication  -  1.0
# EE6110 - Adaptive Signal Processing  -  0.19823986317056053
# EE6133 - Multirate Digital Signal Processing  -  0.9373882913710767
# EE6140 - Multi-Antenna Digital Communications  -  0.7406907593850465
# EE6143 - Advanced Topics in Communications  -  0.5437713091520254
# EE6200 - Power Electronic Control of Electric Machines  -  0.8927537907700456
# EE6258 - DC Power Transmission Systems  -  0.48247555939075504
# EE6265 - Power System Operation and Planning  -  1.0
# EE6324 - Phase-Locked Loops  -  0.33052608497541236
# EE6326 - Integrated Circuit Design and Testing  -  0.45560514958746035
# EE6417 - Allied Topics in Control Systems  -  0.6025843770797518
# EE6700 - Advanced Photonics Laboratory  -  0.6309297535714575
#
#  Average nDCG =  0.7379722852140798

# %% [markdown]
# For EE vs All courses

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'EE-ALL'
scope = 'one-vs-all'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_all_wiki_esa_similarity_matrix, ee_all_wiki_esa_evaluation_matrix, ee_all_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# EE1100 - Basic Electrical Engineering  -  0.7168870397122132
# EE1102 - Introduction to Programming  -  0.8554425550666684
# EE1103 - Numerical Methods  -  0.8490218563706889
# EE2015 - Electric Circuits & Networks  -  0.7774223325720087
# EE2016 - Microprocessor Theory+Lab  -  0.9407662247971147
# EE2025 - Engineering Electromagnetics  -  0.7883652551752491
# EE3002 - Analog Circuits  -  0.901550651686529
# EE3003 - Power Systems  -  0.5
# EE3004 - Control Engineering  -  0.5894709850015082
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.9049290155679591
# EE3301 - Introduction to Semiconductor Devices  -  0.9790270241138814
# EE3313 - Device Modelling  -  0.9296259785920711
# EE4140 - Digital Communication Systems  -  0.8144393422063176
# EE4371 - Introduction to Data Structures and Algorithms  -  0.9918291064614978
# EE4502 - Optics for Engineers  -  0.900026351878831
# EE4708 - Data Analytics Laboratory  -  0.8419451045923748
# EE5011 - Computer Methods in Electrical Engineering  -  0.6563164163700933
# EE5110 - Probability Foundations for Electrical Engineers  -  0.8568454842957778
# EE5120 - Applied Linear Algebra I for EE  -  0.8816601613006391
# EE5130 - Digital Signal Processing  -  0.8796996310351194
# EE5140 - Digital Modulation and Coding  -  0.6497612733887366
# EE5143 - Information Theory  -  0.6240505200038379
# EE5151 - Communication Techniques  -  0.5526447223070572
# EE5200 - Power Converter Analysis and Design  -  0.7405267087344727
# EE5201 - Modelling and Analysis of Electric Machines  -  0.6508369297752947
# EE5204 - Electric Vehicles and Renewable Energy  -  0.7676901535879155
# EE5212 - Digital Controller for power Applications  -  0.41733594329180324
# EE5253 - Computer Methods in Power Systems Analysis  -  0.6038065535500149
# EE5262 - Distributed Generation and Microgrid Systems  -  0.7864084539454089
# EE5310 - Analog Electronic circuits  -  0.9429277415462606
# EE5311 - Digital IC Design  -  0.7577519836518881
# EE5312 - VLSI Technology  -  0.7732581135867117
# EE5313 - Semiconductor Device Modelling  -  0.9642007826805433
# EE5325 - Power Management Integrated Circuits  -  0.6385791815931011
# EE5346 - Introduction to Plastic Electronics  -  0.24465054211822604
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.7998412183747893
# EE5400 - Analog and Digital Circuits  -  0.8539840092220101
# EE5410 - Introduction to DSP  -  0.7949161233608768
# EE5412 - Mathematical Methods in System Engineering  -  0.8026643769252341
# EE5413 - Linear Dynamical Systems  -  0.6743433043078849
# EE5502 - Optical Engineering  -  0.9255364854752296
# EE5505 - Wave Propagation in Communication  -  0.7977738342386859
# EE6110 - Adaptive Signal Processing  -  0.13511907721365987
# EE6133 - Multirate Digital Signal Processing  -  0.9049966534197992
# EE6140 - Multi-Antenna Digital Communications  -  0.7044675341429344
# EE6143 - Advanced Topics in Communications  -  0.8848644297311188
# EE6200 - Power Electronic Control of Electric Machines  -  0.8927537907700456
# EE6258 - DC Power Transmission Systems  -  0.500169791634947
# EE6265 - Power System Operation and Planning  -  0.7601041640010942
# EE6324 - Phase-Locked Loops  -  0.3950354081474819
# EE6326 - Integrated Circuit Design and Testing  -  0.2754979738039799
# EE6417 - Allied Topics in Control Systems  -  0.6547084162934179
# EE6700 - Advanced Photonics Laboratory  -  0.4425579927081062
#
#  Average nDCG =  0.7333780132892282

# %% [markdown]
# # esa with other Universities contents

# %%
folder = '../codes/dataset/saved/without_phrases/'

phrases = []
abbreviations = {}
with_stemming = 'no'

course_detail_path = "../codes/dataset/CourseData.csv"
preprocessing = Preprocessing(phrases, abbreviations, with_stemming)
document_content = preprocessing.readCourseData(course_detail_path)
try:
    other_university_document_esa_matrix = np.load(folder + 'other_university_document_esa_matrix.npy')
    other_university_query_esa_matrix = np.load(folder + 'other_university_query_esa_matrix.npy')
    other_university_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')
except:
    base_path = '../codes/dataset/other_unversities_contents.json'
    base_content = preprocessing.readDictionary(base_path)

    esa = ESA(base_content, document_content, document_content, "same")
    other_university_document_esa_matrix, other_university_query_esa_matrix, other_university_esa_similarity_matrix = esa.computation()

    np.save(folder + 'other_university_document_esa_matrix.npy', other_university_document_esa_matrix)
    np.save(folder + 'other_university_query_esa_matrix.npy', other_university_query_esa_matrix)
    np.save(folder + 'other_university_esa_similarity_matrix.npy', other_university_esa_similarity_matrix)

# %% [markdown]
# For CS vs CS courses

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'CS-CS'
scope = 'one-vs-one'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
other_university_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, other_university_esa_similarity_matrix, dept, scope)
cs_cs_other_university_esa_similarity_matrix, cs_cs_other_university_esa_evaluation_matrix, cs_cs_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# CS1100 - Introduction to Programming  -  0.983303248698947
# CS1111 - Problem Solving using Computers  -  0.9747429528567879
# CS2300 - Foundations of Computer Systems Design  -  0.9668342083190152
# CS2310 - Foundations of Computer Systems Design Lab  -  0.9485379968639579
# CS2700 - Programming and Data Structures  -  0.9407574315943523
# CS2710 - Programming and Data Structures Lab  -  0.9491546172962253
# CS3100 - Paradigms of Programming  -  0.9242560749182924
# CS3300 - Compiler Design  -  0.23137821315975915
# CS3500 - Operating Systems  -  1.0
# CS3700 - Introduction to Database Systems  -  nan
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.8756595247647427
# CS5691 - Pattern Recognition and Machine Learning  -  0.9731203984025375
# CS5800 - Advanced Data Structures & Algorithms  -  0.9572022199008637
# CS6014 - Computability and Complexity  -  0.8723047062986427
# CS6015 - Linear Algebra and Random Processes  -  0.9469024295259745
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.9243493966252967
# CS6030 - Logic and Combinatorics for Computer Science  -  0.6635180404361359
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.23540891336663824
# CS6130 - Advanced Graph Algorithms  -  0.6978817289434457
# CS6140 - Advanced Programming Laboratory  -  0.9498751896215565
# CS6170 - Randomized Algorithms  -  0.9197207891481876
# CS6230 - CAD for VLSI Systems  -  0.8600841191887266
# CS6251 - Computational Models of Cognition  -  0.4730087760751325
# CS6350 - Computer Vision  -  0.9024049875019746
# CS6380 - Artificial Intelligence  -  0.7870548717322928
# CS6570 - Secure Systems Engineering  -  0.9673462154445368
# CS6600 - Computer Architecture  -  0.9619991470595832
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.9303863211094884
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.7982650576674577
# CS7016 - Topics In Deep Learning  -  1.0
# CS7111 - Topics in Cryptography  -  1.0
#
#  Average nDCG =  0.8604743239271481

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'CS-ALL'
scope = 'one-vs-all'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
other_university_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, other_university_esa_similarity_matrix, dept, scope)
cs_all_other_university_esa_similarity_matrix, cs_all_other_university_esa_evaluation_matrix, cs_all_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# CS1100 - Introduction to Programming  -  0.9643250515144093
# CS1111 - Problem Solving using Computers  -  0.9515218318032107
# CS2300 - Foundations of Computer Systems Design  -  0.9049198721403465
# CS2310 - Foundations of Computer Systems Design Lab  -  0.846575407481123
# CS2700 - Programming and Data Structures  -  0.9298450693204839
# CS2710 - Programming and Data Structures Lab  -  0.898359252361489
# CS3100 - Paradigms of Programming  -  0.8480003543575312
# CS3300 - Compiler Design  -  0.31002180716128847
# CS3500 - Operating Systems  -  0.9619991470595832
# CS3700 - Introduction to Database Systems  -  0.7030069601745773
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.9060510245274176
# CS5691 - Pattern Recognition and Machine Learning  -  0.9424055584553004
# CS5800 - Advanced Data Structures & Algorithms  -  0.9012774908849868
# CS6014 - Computability and Complexity  -  0.8291451474534715
# CS6015 - Linear Algebra and Random Processes  -  0.9553626677401832
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.8208421936388406
# CS6030 - Logic and Combinatorics for Computer Science  -  0.9129221442017558
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.6226420321914099
# CS6130 - Advanced Graph Algorithms  -  0.7434506530875773
# CS6140 - Advanced Programming Laboratory  -  0.9407437851838004
# CS6170 - Randomized Algorithms  -  0.6697795367337823
# CS6230 - CAD for VLSI Systems  -  0.6691272440069502
# CS6251 - Computational Models of Cognition  -  0.40817864210039606
# CS6350 - Computer Vision  -  0.7652175773160123
# CS6380 - Artificial Intelligence  -  0.8001036820605906
# CS6570 - Secure Systems Engineering  -  0.8257931229274268
# CS6600 - Computer Architecture  -  0.9182523604040996
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.886684232013298
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.8662320226352063
# CS7016 - Topics In Deep Learning  -  0.8772153153380493
# CS7111 - Topics in Cryptography  -  0.47817314861201765
#
#  Average nDCG =  0.8175119734556002

# %% [markdown]
# For EE vs EE courses

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'EE-EE'
scope = 'one-vs-one'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
other_university_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_ee_other_university_esa_similarity_matrix, ee_ee_other_university_esa_evaluation_matrix, ee_ee_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# EE1100 - Basic Electrical Engineering  -  0.6212101921659198
# EE1102 - Introduction to Programming  -  nan
# EE1103 - Numerical Methods  -  0.5249810332008933
# EE2015 - Electric Circuits & Networks  -  0.7859852846207472
# EE2016 - Microprocessor Theory+Lab  -  nan
# EE2025 - Engineering Electromagnetics  -  0.8503449055347546
# EE3002 - Analog Circuits  -  0.9186560662081473
# EE3003 - Power Systems  -  0.5
# EE3004 - Control Engineering  -  0.823515575213343
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.6583856728354838
# EE3301 - Introduction to Semiconductor Devices  -  0.9372375429818208
# EE3313 - Device Modelling  -  0.9350976551237904
# EE4140 - Digital Communication Systems  -  0.9043980816456215
# EE4371 - Introduction to Data Structures and Algorithms  -  nan
# EE4502 - Optics for Engineers  -  1.0
# EE4708 - Data Analytics Laboratory  -  0.43067655807339306
# EE5011 - Computer Methods in Electrical Engineering  -  0.6309297535714575
# EE5110 - Probability Foundations for Electrical Engineers  -  0.6537031097682611
# EE5120 - Applied Linear Algebra I for EE  -  0.8854598815714874
# EE5130 - Digital Signal Processing  -  0.824055711564085
# EE5140 - Digital Modulation and Coding  -  0.7611962717758727
# EE5143 - Information Theory  -  1.0
# EE5151 - Communication Techniques  -  0.6521602615416859
# EE5200 - Power Converter Analysis and Design  -  0.7603225892217418
# EE5201 - Modelling and Analysis of Electric Machines  -  0.6663732474096913
# EE5204 - Electric Vehicles and Renewable Energy  -  0.9197207891481876
# EE5212 - Digital Controller for power Applications  -  0.322377339362118
# EE5253 - Computer Methods in Power Systems Analysis  -  0.8424910786679212
# EE5262 - Distributed Generation and Microgrid Systems  -  0.8029580725803853
# EE5310 - Analog Electronic circuits  -  0.9590729006026163
# EE5311 - Digital IC Design  -  0.8502983370860306
# EE5312 - VLSI Technology  -  0.9630942302367672
# EE5313 - Semiconductor Device Modelling  -  0.9565912771023182
# EE5325 - Power Management Integrated Circuits  -  0.6528604065555543
# EE5346 - Introduction to Plastic Electronics  -  0.5
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.3562071871080222
# EE5400 - Analog and Digital Circuits  -  0.7328286204777911
# EE5410 - Introduction to DSP  -  0.7421923726567936
# EE5412 - Mathematical Methods in System Engineering  -  0.8385465274895063
# EE5413 - Linear Dynamical Systems  -  0.9197207891481876
# EE5502 - Optical Engineering  -  1.0
# EE5505 - Wave Propagation in Communication  -  1.0
# EE6110 - Adaptive Signal Processing  -  0.19823986317056053
# EE6133 - Multirate Digital Signal Processing  -  0.9373882913710767
# EE6140 - Multi-Antenna Digital Communications  -  0.7406907593850465
# EE6143 - Advanced Topics in Communications  -  0.5437713091520254
# EE6200 - Power Electronic Control of Electric Machines  -  0.8927537907700456
# EE6258 - DC Power Transmission Systems  -  0.48247555939075504
# EE6265 - Power System Operation and Planning  -  1.0
# EE6324 - Phase-Locked Loops  -  0.33052608497541236
# EE6326 - Integrated Circuit Design and Testing  -  0.45560514958746035
# EE6417 - Allied Topics in Control Systems  -  0.6025843770797518
# EE6700 - Advanced Photonics Laboratory  -  0.6309297535714575
#
#  Average nDCG =  0.7379722852140798

# %% [markdown]
# For EE vs All courses

# %%
folder = '../codes/dataset/saved/without_phrases/'
dept = 'EE-ALL'
scope = 'one-vs-all'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
other_university_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_all_other_university_esa_similarity_matrix, ee_all_other_university_esa_evaluation_matrix, ee_all_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# EE1100 - Basic Electrical Engineering  -  0.7168870397122132
# EE1102 - Introduction to Programming  -  0.8554425550666684
# EE1103 - Numerical Methods  -  0.8490218563706889
# EE2015 - Electric Circuits & Networks  -  0.7774223325720087
# EE2016 - Microprocessor Theory+Lab  -  0.9407662247971147
# EE2025 - Engineering Electromagnetics  -  0.7883652551752491
# EE3002 - Analog Circuits  -  0.901550651686529
# EE3003 - Power Systems  -  0.5
# EE3004 - Control Engineering  -  0.5894709850015082
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.9049290155679591
# EE3301 - Introduction to Semiconductor Devices  -  0.9790270241138814
# EE3313 - Device Modelling  -  0.9296259785920711
# EE4140 - Digital Communication Systems  -  0.8144393422063176
# EE4371 - Introduction to Data Structures and Algorithms  -  0.9918291064614978
# EE4502 - Optics for Engineers  -  0.900026351878831
# EE4708 - Data Analytics Laboratory  -  0.8419451045923748
# EE5011 - Computer Methods in Electrical Engineering  -  0.6563164163700933
# EE5110 - Probability Foundations for Electrical Engineers  -  0.8568454842957778
# EE5120 - Applied Linear Algebra I for EE  -  0.8816601613006391
# EE5130 - Digital Signal Processing  -  0.8796996310351194
# EE5140 - Digital Modulation and Coding  -  0.6497612733887366
# EE5143 - Information Theory  -  0.6240505200038379
# EE5151 - Communication Techniques  -  0.5526447223070572
# EE5200 - Power Converter Analysis and Design  -  0.7405267087344727
# EE5201 - Modelling and Analysis of Electric Machines  -  0.6508369297752947
# EE5204 - Electric Vehicles and Renewable Energy  -  0.7676901535879155
# EE5212 - Digital Controller for power Applications  -  0.41733594329180324
# EE5253 - Computer Methods in Power Systems Analysis  -  0.6038065535500149
# EE5262 - Distributed Generation and Microgrid Systems  -  0.7864084539454089
# EE5310 - Analog Electronic circuits  -  0.9429277415462606
# EE5311 - Digital IC Design  -  0.7577519836518881
# EE5312 - VLSI Technology  -  0.7732581135867117
# EE5313 - Semiconductor Device Modelling  -  0.9642007826805433
# EE5325 - Power Management Integrated Circuits  -  0.6385791815931011
# EE5346 - Introduction to Plastic Electronics  -  0.24465054211822604
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.7998412183747893
# EE5400 - Analog and Digital Circuits  -  0.8539840092220101
# EE5410 - Introduction to DSP  -  0.7949161233608768
# EE5412 - Mathematical Methods in System Engineering  -  0.8026643769252341
# EE5413 - Linear Dynamical Systems  -  0.6743433043078849
# EE5502 - Optical Engineering  -  0.9255364854752296
# EE5505 - Wave Propagation in Communication  -  0.7977738342386859
# EE6110 - Adaptive Signal Processing  -  0.13511907721365987
# EE6133 - Multirate Digital Signal Processing  -  0.9049966534197992
# EE6140 - Multi-Antenna Digital Communications  -  0.7044675341429344
# EE6143 - Advanced Topics in Communications  -  0.8848644297311188
# EE6200 - Power Electronic Control of Electric Machines  -  0.8927537907700456
# EE6258 - DC Power Transmission Systems  -  0.500169791634947
# EE6265 - Power System Operation and Planning  -  0.7601041640010942
# EE6324 - Phase-Locked Loops  -  0.3950354081474819
# EE6326 - Integrated Circuit Design and Testing  -  0.2754979738039799
# EE6417 - Allied Topics in Control Systems  -  0.6547084162934179
# EE6700 - Advanced Photonics Laboratory  -  0.4425579927081062
#
#  Average nDCG =  0.7333780132892282

# %% [markdown]
# # with phrases other Universities contents ESA¶

# %%
folder = '../codes/dataset/Dictionary_text/'
with open(folder+'Complete_Glossary1.txt', 'r', encoding='utf-8') as file:
    glossary = file.readlines()

ps = PorterStemmer()

phrases = []
for word in glossary:
    phrases.append(ps.stem(word.replace('\n', '')))

# %%
folder = '../codes/dataset/saved/with_phrases/'

# phrases = []
abbreviations = {}
with_stemming = 'no'

course_detail_path = "../codes/dataset/CourseData.csv"
preprocessing = Preprocessing(phrases, abbreviations, with_stemming)
try:
    document_content = jsonload(folder + 'Course_Data_with_phrases.json')
except:
    document_content = preprocessing.readCourseData(course_detail_path)
    jsondump(document_content, folder + 'Course_Data_with_phrases.json')
    
try:
    other_university_document_esa_matrix = np.load(folder + 'other_university_document_esa_matrix.npy')
    other_university_query_esa_matrix = np.load(folder + 'other_university_query_esa_matrix.npy')
    other_university_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')
except:
    try:
        base_content = jsonload(folder + 'other_unversities_contents_with_phrases.json')
    except:
        base_path = '../codes/dataset/other_unversities_contents.json'
        base_content = preprocessing.readDictionary(base_path)
        jsondump(base_content, folder + 'other_unversities_contents_with_phrases.json')

    esa = ESA(base_content, document_content, document_content, "same")
    other_university_document_esa_matrix, other_university_query_esa_matrix, other_university_esa_similarity_matrix = esa.computation()

    np.save(folder + 'other_university_document_esa_matrix.npy', other_university_document_esa_matrix)
    np.save(folder + 'other_university_query_esa_matrix.npy', other_university_query_esa_matrix)
    np.save(folder + 'other_university_esa_similarity_matrix.npy', other_university_esa_similarity_matrix)

# For CS vs CS courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'CS-CS'
scope = 'one-vs-one'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, other_university_esa_similarity_matrix, dept, scope)
cs_cs_other_university_esa_similarity_matrix, cs_cs_other_university_esa_evaluation_matrix, cs_cs_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)

# For CS vs ALL courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'CS-ALL'
scope = 'one-vs-all'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, other_university_esa_similarity_matrix, dept, scope)
cs_all_other_university_esa_similarity_matrix, cs_all_other_university_esa_evaluation_matrix, cs_all_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)

# For EE vs EE courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'EE-EE'
scope = 'one-vs-one'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_ee_other_university_esa_similarity_matrix, ee_ee_other_university_esa_evaluation_matrix, ee_ee_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)

# For EE vs All courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'EE-ALL'
scope = 'one-vs-all'
method = 'other_university_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'other_university_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_all_other_university_esa_similarity_matrix, ee_all_other_university_esa_evaluation_matrix, ee_all_other_university_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# CS1100 - Introduction to Programming  -  0.983303248698947
# CS1111 - Problem Solving using Computers  -  0.9669850519151657
# CS2300 - Foundations of Computer Systems Design  -  0.9668342083190152
# CS2310 - Foundations of Computer Systems Design Lab  -  0.9455856780856265
# CS2700 - Programming and Data Structures  -  0.9210504394261853
# CS2710 - Programming and Data Structures Lab  -  0.9491546172962253
# CS3100 - Paradigms of Programming  -  0.9391664772645913
# CS3300 - Compiler Design  -  0.23137821315975915
# CS3500 - Operating Systems  -  1.0
# CS3700 - Introduction to Database Systems  -  nan
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.890235195578859
# CS5691 - Pattern Recognition and Machine Learning  -  0.9591390361068151
# CS5800 - Advanced Data Structures & Algorithms  -  0.9559667565543964
# CS6014 - Computability and Complexity  -  0.8843252268199594
# CS6015 - Linear Algebra and Random Processes  -  0.9469024295259745
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.9243493966252967
# CS6030 - Logic and Combinatorics for Computer Science  -  0.7032379526954946
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.25
# CS6130 - Advanced Graph Algorithms  -  0.7122630665145961
# CS6140 - Advanced Programming Laboratory  -  0.9498751896215565
# CS6170 - Randomized Algorithms  -  0.9197207891481876
# CS6230 - CAD for VLSI Systems  -  0.7986415712342395
# CS6251 - Computational Models of Cognition  -  0.4710724773036006
# CS6350 - Computer Vision  -  0.9003166658666569
# CS6380 - Artificial Intelligence  -  0.5951048612534623
# CS6570 - Secure Systems Engineering  -  0.9540850426721298
# CS6600 - Computer Architecture  -  0.9550236580992476
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.933819260234181
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.7982650576674577
# CS7016 - Topics In Deep Learning  -  1.0
# CS7111 - Topics in Cryptography  -  1.0
#
#  Average nDCG =  0.8539225736511191
# CS1100 - Introduction to Programming  -  0.9638512119019819
# CS1111 - Problem Solving using Computers  -  0.9399313288985855
# CS2300 - Foundations of Computer Systems Design  -  0.8922140133206836
# CS2310 - Foundations of Computer Systems Design Lab  -  0.7878539176558598
# CS2700 - Programming and Data Structures  -  0.9171311479191973
# CS2710 - Programming and Data Structures Lab  -  0.9047524437858315
# CS3100 - Paradigms of Programming  -  0.8641410186973794
# CS3300 - Compiler Design  -  0.31034342927274067
# CS3500 - Operating Systems  -  0.9709286432396583
# CS3700 - Introduction to Database Systems  -  0.39135119253165457
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.9059068950846496
# CS5691 - Pattern Recognition and Machine Learning  -  0.941449895032759
# CS5800 - Advanced Data Structures & Algorithms  -  0.8991019952957566
# CS6014 - Computability and Complexity  -  0.8601854111339846
# CS6015 - Linear Algebra and Random Processes  -  0.9578410747317564
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.8161179341229591
# CS6030 - Logic and Combinatorics for Computer Science  -  0.9284376371821454
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.6234748375073635
# CS6130 - Advanced Graph Algorithms  -  0.7467024084972629
# CS6140 - Advanced Programming Laboratory  -  0.937219850130508
# CS6170 - Randomized Algorithms  -  0.6678278711694311
# CS6230 - CAD for VLSI Systems  -  0.6631933225926848
# CS6251 - Computational Models of Cognition  -  0.4130706664427399
# CS6350 - Computer Vision  -  0.7657870297965483
# CS6380 - Artificial Intelligence  -  0.7007525689459705
# CS6570 - Secure Systems Engineering  -  0.7686587579408621
# CS6600 - Computer Architecture  -  0.8979238794339472
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.8873266885784162
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.8695559758135332
# CS7016 - Topics In Deep Learning  -  0.8772153153380493
# CS7111 - Topics in Cryptography  -  0.4772693635989836
#
#  Average nDCG =  0.8020375307497597
# EE1100 - Basic Electrical Engineering  -  0.6714461420013242
# EE1102 - Introduction to Programming  -  nan
# EE1103 - Numerical Methods  -  0.5706417189553201
# EE2015 - Electric Circuits & Networks  -  0.7428247905257434
# EE2016 - Microprocessor Theory+Lab  -  nan
# EE2025 - Engineering Electromagnetics  -  0.7550160946314525
# EE3002 - Analog Circuits  -  0.8613672382595493
# EE3003 - Power Systems  -  0.43067655807339306
# EE3004 - Control Engineering  -  0.85214574550725
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.6821028252649194
# EE3301 - Introduction to Semiconductor Devices  -  0.8980061802949083
# EE3313 - Device Modelling  -  0.9372326238128186
# EE4140 - Digital Communication Systems  -  0.9747429528567879
# EE4371 - Introduction to Data Structures and Algorithms  -  nan
# EE4502 - Optics for Engineers  -  1.0
# EE4708 - Data Analytics Laboratory  -  0.43067655807339306
# EE5011 - Computer Methods in Electrical Engineering  -  0.6309297535714575
# EE5110 - Probability Foundations for Electrical Engineers  -  0.6765535694457451
# EE5120 - Applied Linear Algebra I for EE  -  0.8529278650606567
# EE5130 - Digital Signal Processing  -  0.8546728357469291
# EE5140 - Digital Modulation and Coding  -  0.8538910254266521
# EE5143 - Information Theory  -  1.0
# EE5151 - Communication Techniques  -  0.692152050219084
# EE5200 - Power Converter Analysis and Design  -  0.8177501103848478
# EE5201 - Modelling and Analysis of Electric Machines  -  0.7103828958604769
# EE5204 - Electric Vehicles and Renewable Energy  -  0.9197207891481876
# EE5212 - Digital Controller for power Applications  -  0.4421188146690532
# EE5253 - Computer Methods in Power Systems Analysis  -  0.8328969907147487
# EE5262 - Distributed Generation and Microgrid Systems  -  0.9132861715058802
# EE5310 - Analog Electronic circuits  -  0.8988278058975984
# EE5311 - Digital IC Design  -  0.9207545636271999
# EE5312 - VLSI Technology  -  0.7800989336685674
# EE5313 - Semiconductor Device Modelling  -  0.9456352704673577
# EE5325 - Power Management Integrated Circuits  -  0.6771471913981634
# EE5346 - Introduction to Plastic Electronics  -  0.5
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.3562071871080222
# EE5400 - Analog and Digital Circuits  -  1.0
# EE5410 - Introduction to DSP  -  0.713659395478714
# EE5412 - Mathematical Methods in System Engineering  -  0.8179809735263114
# EE5413 - Linear Dynamical Systems  -  0.9197207891481876
# EE5502 - Optical Engineering  -  1.0
# EE5505 - Wave Propagation in Communication  -  1.0
# EE6110 - Adaptive Signal Processing  -  0.23137821315975915
# EE6133 - Multirate Digital Signal Processing  -  0.9585880102367398
# EE6140 - Multi-Antenna Digital Communications  -  0.7841802768331765
# EE6143 - Advanced Topics in Communications  -  0.6052602440527057
# EE6200 - Power Electronic Control of Electric Machines  -  0.7226387152952866
# EE6258 - DC Power Transmission Systems  -  0.46845052016107697
# EE6265 - Power System Operation and Planning  -  0.9469024295259745
# EE6324 - Phase-Locked Loops  -  0.4598603945740938
# EE6326 - Integrated Circuit Design and Testing  -  0.3706656904013186
# EE6417 - Allied Topics in Control Systems  -  0.6032524720984396
# EE6700 - Advanced Photonics Laboratory  -  1.0
#
#  Average nDCG =  0.7537074275333855
# EE1100 - Basic Electrical Engineering  -  0.7027805161477872
# EE1102 - Introduction to Programming  -  0.8835952539716344
# EE1103 - Numerical Methods  -  0.8285315150899448
# EE2015 - Electric Circuits & Networks  -  0.7243410327462216
# EE2016 - Microprocessor Theory+Lab  -  0.8562307498774919
# EE2025 - Engineering Electromagnetics  -  0.7749352988303391
# EE3002 - Analog Circuits  -  0.8049753034741485
# EE3003 - Power Systems  -  0.43067655807339306
# EE3004 - Control Engineering  -  0.6120578977971219
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.8932977907264917
# EE3301 - Introduction to Semiconductor Devices  -  0.902479282559369
# EE3313 - Device Modelling  -  0.859464968614899
# EE4140 - Digital Communication Systems  -  0.9143656167316339
# EE4371 - Introduction to Data Structures and Algorithms  -  0.9670943502702474
# EE4502 - Optics for Engineers  -  0.9828920819566879
# EE4708 - Data Analytics Laboratory  -  0.8706505049163871
# EE5011 - Computer Methods in Electrical Engineering  -  0.7728323622600022
# EE5110 - Probability Foundations for Electrical Engineers  -  0.8346377055129698
# EE5120 - Applied Linear Algebra I for EE  -  0.8804228103995142
# EE5130 - Digital Signal Processing  -  0.8389862421576896
# EE5140 - Digital Modulation and Coding  -  0.7558131853313804
# EE5143 - Information Theory  -  0.6934264036172708
# EE5151 - Communication Techniques  -  0.6827211834463348
# EE5200 - Power Converter Analysis and Design  -  0.7640379023239096
# EE5201 - Modelling and Analysis of Electric Machines  -  0.6344759046019999
# EE5204 - Electric Vehicles and Renewable Energy  -  0.7080598604233176
# EE5212 - Digital Controller for power Applications  -  0.4014903639545999
# EE5253 - Computer Methods in Power Systems Analysis  -  0.6725890578118865
# EE5262 - Distributed Generation and Microgrid Systems  -  0.8536898979297227
# EE5310 - Analog Electronic circuits  -  0.9019477052660073
# EE5311 - Digital IC Design  -  0.9550626642149025
# EE5312 - VLSI Technology  -  0.4656734545406255
# EE5313 - Semiconductor Device Modelling  -  0.8832334760367532
# EE5325 - Power Management Integrated Circuits  -  0.6572610236791879
# EE5346 - Introduction to Plastic Electronics  -  0.22106472945750374
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.7623170083502321
# EE5400 - Analog and Digital Circuits  -  0.9459822106061088
# EE5410 - Introduction to DSP  -  0.7672117398998307
# EE5412 - Mathematical Methods in System Engineering  -  0.838827773866126
# EE5413 - Linear Dynamical Systems  -  0.9005471983095722
# EE5502 - Optical Engineering  -  1.0
# EE5505 - Wave Propagation in Communication  -  0.860997317057002
# EE6110 - Adaptive Signal Processing  -  0.1515171524096389
# EE6133 - Multirate Digital Signal Processing  -  0.8934626204436992
# EE6140 - Multi-Antenna Digital Communications  -  0.7486924110517823
# EE6143 - Advanced Topics in Communications  -  0.8972231277676632
# EE6200 - Power Electronic Control of Electric Machines  -  0.7053571733135213
# EE6258 - DC Power Transmission Systems  -  0.47585327001382216
# EE6265 - Power System Operation and Planning  -  0.718669095766698
# EE6324 - Phase-Locked Loops  -  0.4698929417755237
# EE6326 - Integrated Circuit Design and Testing  -  0.2142041721713589
# EE6417 - Allied Topics in Control Systems  -  0.6811618816569205
# EE6700 - Advanced Photonics Laboratory  -  0.6425804535808055
#
#  Average nDCG =  0.7407602302413148

# %% [markdown]
# # with phrases wikipedia ESA

# %%
folder = '../codes/dataset/Dictionary_text/'
with open(folder+'Complete_Glossary1.txt', 'r', encoding='utf-8') as file:
    glossary = file.readlines()

ps = PorterStemmer()
    
phrases = []
for word in glossary:
    phrases.append(ps.stem(word.replace('\n', '')))

# %%
folder = '../codes/dataset/saved/with_phrases/'

# phrases = []
abbreviations = {}
with_stemming = 'no'

course_detail_path = "../codes/dataset/CourseData.csv"
preprocessing = Preprocessing(phrases, abbreviations, with_stemming)
try:
    document_content = jsonload(folder + 'Course_Data_with_phrases.json')
except:
    document_content = preprocessing.readCourseData(course_detail_path)
    jsondump(document_content, folder + 'Course_Data_with_phrases.json')
    
try:
    wiki_document_esa_matrix = np.load(folder + 'wiki_document_esa_matrix.npy')
    wiki_query_esa_matrix = np.load(folder + 'wiki_query_esa_matrix.npy')
    wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')
except:
    try:
        base_content = jsonload(folder + 'Wikipedia_Articles_with_phrases.json')
    except:
        wikipedia_articles_path = "../codes/dataset/QueriedWikipediaArticles/"
        base_content = preprocessing.readWikipediaData(wikipedia_articles_path)
        jsondump(base_content, folder + 'Wikipedia_Articles_with_phrases.json')

    
    esa = ESA(base_content, document_content, document_content, "same")
    wiki_document_esa_matrix, wiki_query_esa_matrix, wiki_esa_similarity_matrix = esa.computation()

    np.save(folder + 'wiki_document_esa_matrix.npy', wiki_document_esa_matrix)
    np.save(folder + 'wiki_query_esa_matrix.npy', wiki_query_esa_matrix)
    np.save(folder + 'wiki_esa_similarity_matrix.npy', wiki_esa_similarity_matrix)

# For CS vs CS courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'CS-CS'
scope = 'one-vs-one'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
cs_cs_wiki_esa_similarity_matrix, cs_cs_wiki_esa_evaluation_matrix, cs_cs_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)

# For CS vs All courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'CS-ALL'
scope = 'one-vs-all'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/Revised_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
cs_all_wiki_esa_similarity_matrix, cs_all_wiki_esa_evaluation_matrix, cs_all_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)

# For EE vs EE courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'EE-EE'
scope = 'one-vs-one'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_ee_wiki_esa_similarity_matrix, ee_ee_wiki_esa_evaluation_matrix, ee_ee_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)

# For EE vs All courses

folder = '../codes/dataset/saved/with_phrases/'
dept = 'EE-ALL'
scope = 'one-vs-all'
method = 'wiki_esa'

eval_matrix_path = "../codes/dataset/EE_EvaluationData.txt"
titles, _ = ESA({}, {}, {}, "same").dict_to_list(document_content)
wiki_esa_similarity_matrix = np.load(folder + 'wiki_esa_similarity_matrix.npy')

evaluation = Evaluation(eval_matrix_path, titles, wiki_esa_similarity_matrix, dept, scope)
ee_all_wiki_esa_similarity_matrix, ee_all_wiki_esa_evaluation_matrix, ee_all_wiki_esa_coursewise_ndcg = evaluation.printing(folder, method)
# Out:
# CS1100 - Introduction to Programming  -  0.9766196540579892
# CS1111 - Problem Solving using Computers  -  0.975788054854922
# CS2300 - Foundations of Computer Systems Design  -  0.9634012691943225
# CS2310 - Foundations of Computer Systems Design Lab  -  0.9284591831945489
# CS2700 - Programming and Data Structures  -  0.9152674746510859
# CS2710 - Programming and Data Structures Lab  -  0.9603909229238758
# CS3100 - Paradigms of Programming  -  0.9391222304037579
# CS3300 - Compiler Design  -  0.23981246656813146
# CS3500 - Operating Systems  -  0.9619991470595832
# CS3700 - Introduction to Database Systems  -  nan
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.9024049875019746
# CS5691 - Pattern Recognition and Machine Learning  -  0.9178260148263059
# CS5800 - Advanced Data Structures & Algorithms  -  0.9547851288814769
# CS6014 - Computability and Complexity  -  0.8723047062986427
# CS6015 - Linear Algebra and Random Processes  -  0.9134015924715543
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.8176892325203015
# CS6030 - Logic and Combinatorics for Computer Science  -  0.6549690465275356
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.24465054211822604
# CS6130 - Advanced Graph Algorithms  -  0.6871475159848289
# CS6140 - Advanced Programming Laboratory  -  0.9911205770005563
# CS6170 - Randomized Algorithms  -  0.6934264036172708
# CS6230 - CAD for VLSI Systems  -  0.7446762637646603
# CS6251 - Computational Models of Cognition  -  0.4320030606958183
# CS6350 - Computer Vision  -  0.895135413424339
# CS6380 - Artificial Intelligence  -  0.5077487620466646
# CS6570 - Secure Systems Engineering  -  0.9163114938808046
# CS6600 - Computer Architecture  -  0.9407662247971147
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.9124198864046418
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.9930783166417602
# CS7016 - Topics In Deep Learning  -  1.0
# CS7111 - Topics in Cryptography  -  1.0
#
#  Average nDCG =  0.8366389487956526
# CS1100 - Introduction to Programming  -  0.9468439725492319
# CS1111 - Problem Solving using Computers  -  0.904062189130495
# CS2300 - Foundations of Computer Systems Design  -  0.9154055059559124
# CS2310 - Foundations of Computer Systems Design Lab  -  0.8248762165133499
# CS2700 - Programming and Data Structures  -  0.9192413703479612
# CS2710 - Programming and Data Structures Lab  -  0.9229380203018436
# CS3100 - Paradigms of Programming  -  0.8127940982858934
# CS3300 - Compiler Design  -  0.46074002034223377
# CS3500 - Operating Systems  -  0.9181717238659934
# CS3700 - Introduction to Database Systems  -  0.4959760299904358
# CS5020 - Nonlinear optimisation: Theory and algorithms  -  0.8804616103862218
# CS5691 - Pattern Recognition and Machine Learning  -  0.9293947819548699
# CS5800 - Advanced Data Structures & Algorithms  -  0.8756916428231936
# CS6014 - Computability and Complexity  -  0.8873080850405487
# CS6015 - Linear Algebra and Random Processes  -  0.9523911585159328
# CS6024 - Algorithmic Approaches to Computational Biology  -  0.7408532434871252
# CS6030 - Logic and Combinatorics for Computer Science  -  0.905358329599596
# CS6111 - Foundations of cryptography  -  1.0
# CS6120 - Wireless Communication and Networks  -  0.6147886208197064
# CS6130 - Advanced Graph Algorithms  -  0.729949364049485
# CS6140 - Advanced Programming Laboratory  -  0.9486130828407244
# CS6170 - Randomized Algorithms  -  0.7643458792520368
# CS6230 - CAD for VLSI Systems  -  0.6512790276452846
# CS6251 - Computational Models of Cognition  -  0.5973145866702672
# CS6350 - Computer Vision  -  0.7622278190844172
# CS6380 - Artificial Intelligence  -  0.6953108350060115
# CS6570 - Secure Systems Engineering  -  0.7856717555344142
# CS6600 - Computer Architecture  -  0.9076821078014101
# CS6777 - Optimization Methods for Computer Vision Applications.  -  0.860160224244689
# CS6842 - Algorithmic Algebra  -  0.9197207891481876
# CS7015 - Deep Learning  -  0.8930615140517613
# CS7016 - Topics In Deep Learning  -  0.8315546295836225
# CS7111 - Topics in Cryptography  -  0.766433990956823
#
#  Average nDCG =  0.8188067341145355
# EE1100 - Basic Electrical Engineering  -  0.6641293932183953
# EE1102 - Introduction to Programming  -  nan
# EE1103 - Numerical Methods  -  0.5249810332008933
# EE2015 - Electric Circuits & Networks  -  0.7715909271760312
# EE2016 - Microprocessor Theory+Lab  -  nan
# EE2025 - Engineering Electromagnetics  -  0.7631539858737962
# EE3002 - Analog Circuits  -  0.8928367555710508
# EE3003 - Power Systems  -  0.5
# EE3004 - Control Engineering  -  0.8254773426097731
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.6598868192693241
# EE3301 - Introduction to Semiconductor Devices  -  0.9372375429818208
# EE3313 - Device Modelling  -  0.9400959366440537
# EE4140 - Digital Communication Systems  -  0.8587959739536173
# EE4371 - Introduction to Data Structures and Algorithms  -  nan
# EE4502 - Optics for Engineers  -  1.0
# EE4708 - Data Analytics Laboratory  -  0.43067655807339306
# EE5011 - Computer Methods in Electrical Engineering  -  0.6309297535714575
# EE5110 - Probability Foundations for Electrical Engineers  -  0.6517302005238356
# EE5120 - Applied Linear Algebra I for EE  -  0.8710785440003369
# EE5130 - Digital Signal Processing  -  0.8538910254266521
# EE5140 - Digital Modulation and Coding  -  0.7915802139893415
# EE5143 - Information Theory  -  1.0
# EE5151 - Communication Techniques  -  0.6681747402917083
# EE5200 - Power Converter Analysis and Design  -  0.7732702922682415
# EE5201 - Modelling and Analysis of Electric Machines  -  0.75655483678701
# EE5204 - Electric Vehicles and Renewable Energy  -  0.9197207891481876
# EE5212 - Digital Controller for power Applications  -  0.3254604649035663
# EE5253 - Computer Methods in Power Systems Analysis  -  0.8196336386298686
# EE5262 - Distributed Generation and Microgrid Systems  -  0.8029580725803853
# EE5310 - Analog Electronic circuits  -  0.9310870514567027
# EE5311 - Digital IC Design  -  0.9330795243082165
# EE5312 - VLSI Technology  -  0.957470786387699
# EE5313 - Semiconductor Device Modelling  -  0.9330795243082165
# EE5325 - Power Management Integrated Circuits  -  0.611411813358404
# EE5346 - Introduction to Plastic Electronics  -  0.5
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.3562071871080222
# EE5400 - Analog and Digital Circuits  -  0.7328286204777911
# EE5410 - Introduction to DSP  -  0.738851277627959
# EE5412 - Mathematical Methods in System Engineering  -  0.8179809735263114
# EE5413 - Linear Dynamical Systems  -  0.8772153153380493
# EE5502 - Optical Engineering  -  1.0
# EE5505 - Wave Propagation in Communication  -  1.0
# EE6110 - Adaptive Signal Processing  -  0.1965616322328226
# EE6133 - Multirate Digital Signal Processing  -  0.9106171877566738
# EE6140 - Multi-Antenna Digital Communications  -  0.7381035537885066
# EE6143 - Advanced Topics in Communications  -  0.5012658353418871
# EE6200 - Power Electronic Control of Electric Machines  -  0.9047172294870751
# EE6258 - DC Power Transmission Systems  -  0.5012658353418871
# EE6265 - Power System Operation and Planning  -  1.0
# EE6324 - Phase-Locked Loops  -  0.35438919069682395
# EE6326 - Integrated Circuit Design and Testing  -  0.45560514958746035
# EE6417 - Allied Topics in Control Systems  -  0.6006487547121568
# EE6700 - Advanced Photonics Laboratory  -  0.6309297535714575
#
#  Average nDCG =  0.7363432207421373
# EE1100 - Basic Electrical Engineering  -  0.7167825001232189
# EE1102 - Introduction to Programming  -  0.847143254255029
# EE1103 - Numerical Methods  -  0.8423110719983323
# EE2015 - Electric Circuits & Networks  -  0.7998066102091443
# EE2016 - Microprocessor Theory+Lab  -  0.9447176050778178
# EE2025 - Engineering Electromagnetics  -  0.7960114177863986
# EE3002 - Analog Circuits  -  0.8790262314194408
# EE3003 - Power Systems  -  0.5
# EE3004 - Control Engineering  -  0.5807386556295729
# EE3006 - Principles of Measurement  -  nan
# EE3110 - Probability Foundations for Electrical Engineers  -  0.9050921858429584
# EE3301 - Introduction to Semiconductor Devices  -  0.9746018986757166
# EE3313 - Device Modelling  -  0.938875238369575
# EE4140 - Digital Communication Systems  -  0.7794920871293282
# EE4371 - Introduction to Data Structures and Algorithms  -  0.9918291064614978
# EE4502 - Optics for Engineers  -  0.9033780850575628
# EE4708 - Data Analytics Laboratory  -  0.8321749727316627
# EE5011 - Computer Methods in Electrical Engineering  -  0.6516980447450663
# EE5110 - Probability Foundations for Electrical Engineers  -  0.8604997043208891
# EE5120 - Applied Linear Algebra I for EE  -  0.8833278082920617
# EE5130 - Digital Signal Processing  -  0.8675022321649103
# EE5140 - Digital Modulation and Coding  -  0.662689439559187
# EE5143 - Information Theory  -  0.6052602440527057
# EE5151 - Communication Techniques  -  0.5565655182626713
# EE5200 - Power Converter Analysis and Design  -  0.7529625644893428
# EE5201 - Modelling and Analysis of Electric Machines  -  0.7103494319412953
# EE5204 - Electric Vehicles and Renewable Energy  -  0.7586746586579408
# EE5212 - Digital Controller for power Applications  -  0.4105607488918906
# EE5253 - Computer Methods in Power Systems Analysis  -  0.6285503452037744
# EE5262 - Distributed Generation and Microgrid Systems  -  0.7870567943021913
# EE5310 - Analog Electronic circuits  -  0.9238884742289976
# EE5311 - Digital IC Design  -  0.8590017977700665
# EE5312 - VLSI Technology  -  0.7841994289935404
# EE5313 - Semiconductor Device Modelling  -  0.9518822870454626
# EE5325 - Power Management Integrated Circuits  -  0.5975947329663817
# EE5346 - Introduction to Plastic Electronics  -  0.24465054211822604
# EE5347 - Electronic and Photonic Nanoscale Devices  -  0.7911861462163119
# EE5400 - Analog and Digital Circuits  -  0.8539090897505806
# EE5410 - Introduction to DSP  -  0.7834229790368272
# EE5412 - Mathematical Methods in System Engineering  -  0.8080597169434561
# EE5413 - Linear Dynamical Systems  -  0.8936878980719799
# EE5502 - Optical Engineering  -  0.9282921230622511
# EE5505 - Wave Propagation in Communication  -  0.7940002326077722
# EE6110 - Adaptive Signal Processing  -  0.13559249537698637
# EE6133 - Multirate Digital Signal Processing  -  0.8909985419413986
# EE6140 - Multi-Antenna Digital Communications  -  0.6995298951256483
# EE6143 - Advanced Topics in Communications  -  0.8775368139585534
# EE6200 - Power Electronic Control of Electric Machines  -  0.9047172294870751
# EE6258 - DC Power Transmission Systems  -  0.5145511292060975
# EE6265 - Power System Operation and Planning  -  0.7598583874172186
# EE6324 - Phase-Locked Loops  -  0.4214732571316536
# EE6326 - Integrated Circuit Design and Testing  -  0.27569239205629237
# EE6417 - Allied Topics in Control Systems  -  0.6506914880863945
# EE6700 - Advanced Photonics Laboratory  -  0.43947314377223123
#
#  Average nDCG =  0.7387088429815585
